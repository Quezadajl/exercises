# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
avocados = pd.read_pickle("../data/avocado.pkl")

# %%
avocados.info()
avocados.value_counts()
avocados.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1014 non-null   object
#  1   type       1014 non-null   object
#  2   year       1014 non-null   int64
#  3   avg_price  1014 non-null   float64
#  4   size       1014 non-null   object
#  5   nb_sold    1014 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 47.7+ KB
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %% [markdown]
# # Visualizing data with Histograms, line plots, and others

# %%
avocados['size'].hist(bins=5)
plt.show()

# %%
avg_avo_price = avocados.groupby('size')['avg_price'].mean()
print(avg_avo_price)
# Out:
# size
# extra_large    1.319024
# large          1.319024
# small          1.319024
# Name: avg_price, dtype: float64

# %%
avg_avo_price.plot(kind='bar',
                  title ="Mean Price by Avocado Size")
plt.show()

# %%
avocados.plot(x='date', y='avg_price', kind='line', rot=45)
plt.show()

# %%
avocados[avocados['size']=='small']['nb_sold'].hist(alpha=0.7)
avocados[avocados['size']=='large']['nb_sold'].hist(alpha=0.7)
plt.legend(['small','large'])
plt.show()

# %%
#get the total number of avocados sold by size & date
nb_sold = avocados.groupby('size')['nb_sold'].sum()
nb_sold.plot(kind='bar')
plt.show()

# %%
nb_sold_by_date = avocados.groupby('date')['nb_sold'].sum()
nb_sold_by_date.plot(x='date', y='nb_sold', kind='line', rot=45)
plt.show()

# %%
avocados.plot(x='nb_sold', y='avg_price', kind='scatter')
plt.show()
